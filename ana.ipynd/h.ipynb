# %%
hari="boomarecrazy"
print=("lenght",len(hari))

# %%
 skill= "data analyst"
# print("lenght",len (skill))
print(skill[4])
print(skill[0.4])
# Out:
#   Cell In[10], line 1
#     skill= "data analyst"
#     ^
# IndentationError: unexpected indent
